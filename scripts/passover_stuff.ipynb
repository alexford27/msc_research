# %% [markdown]
# /Users/alexford/.local/bin/uv run /Users/alexford/Source/repos/msc_research/.venv/bin/python /Users/alexford/Source/repos/msc_research/src/sir_inference/inference/smc/run_smc_5d.py
# Data: ['s', 'e', 'i', 'r'] observed, sigma=0.05, 40 times over [0,80]d
# Truth: beta=0.6, sigma_E=0.2, gamma=0.2, e0=0.005, i0=0.005
#
# SMC in 5D: 2000 particles, ESS target 1000, resample below 1900, 5 move steps, adaptive scale (target accept 0.25)
# step      phi    d_phi     ESS  accept   scale  unique     solves
#    1   0.0010   0.0010   820.6   0.164   0.995    1675      4,914
#    2   0.0026   0.0016  1000.0   0.120   0.819    1399      8,251
#    3   0.0059   0.0034   999.9   0.074   0.629    1075     11,826
#    4   0.0127   0.0068  1000.0   0.051   0.467     859     15,828
#    5   0.0219   0.0092  1000.0   0.058   0.350     893     20,628
#    6   0.0360   0.0141  1000.0   0.085   0.274    1012     26,653
#    7   0.0714   0.0355  1000.0   0.174   0.244    1431     34,183
#    8   0.1248   0.0534  1000.0   0.211   0.230    1765     42,141
#    9   0.2107   0.0859  1000.0   0.312   0.253    1935     50,615
#   10   0.4090   0.1983  1000.0   0.471   0.352    1990     59,401
#   11   0.8767   0.4677  1000.0   0.468   0.488    1990     67,971
#   12   1.0000   0.1233  1938.5   0.378   0.592    1999     76,326
#
# Done: phi=1 in 12 steps, 76,326 ODE solves.
#   beta      = 0.6264 +- 0.0567
#   sigma_E   = 0.1924 +- 0.0165
#   gamma     = 0.2004 +- 0.0197
#   e0        = 0.0060 +- 0.0037
#   i0        = 0.0036 +- 0.0021
#
#   truth      = [0.6   0.2   0.2   0.005 0.005]
#   R0         = 3.130 +- 0.111   (truth 3.0)
#
# Saved -> smc_run_5d.npz  (76,326 solves)
#
# Process finished with exit code 0
